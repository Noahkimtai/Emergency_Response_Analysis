# %%
import pandas as pd
import numpy as np
import os
import glob
import sys

# %%
files = glob.glob('*.csv')
files
# Out:
# ['Surge Response - Italy.csv']

# %%
italyResponse = pd.read_csv('Surge Response - Italy.csv', header = 0, index_col = ['Admin 0', 'Admin 1', 'District'])
italyResponse.head(50)
# Out:
#                             Date of Update (Matrix) Date Completed (Activity)  \
# Admin 0 Admin 1   District
# Italy   Lazio     Roma                       4/9/19                   3/24/19
#                   Roma                       4/9/19                   3/25/19
#                   Roma                       4/9/19                   3/25/19
#                   Roma                       4/9/19                   3/25/19
#                   Roma                       4/9/19                   3/26/19
#                   Roma                       4/9/19                   3/26/19
#                   Roma                       4/9/19                   3/26/19
#                   Roma                       4/9/19                   3/27/19
#                   Roma                       4/9/19                   3/27/19
#                   Roma                       4/9/19                   3/27/19
#                   Roma                       4/9/19                   3/27/19
# ...
